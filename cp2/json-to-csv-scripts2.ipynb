# %%
import csv
import json

# for working with local files
import glob
import os
from os.path import join

#For languages field
# !pip install langcodes
import langcodes

#For ISO Date fields
import re
from datetime import datetime
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langcodes in /Users/jrhym/Library/Python/3.11/lib/python/site-packages (3.5.0)
# Requirement already satisfied: language-data>=1.2 in /Users/jrhym/Library/Python/3.11/lib/python/site-packages (from langcodes) (1.3.0)
# Requirement already satisfied: marisa-trie>=1.1.0 in /Users/jrhym/Library/Python/3.11/lib/python/site-packages (from language-data>=1.2->langcodes) (1.2.1)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from marisa-trie>=1.1.0->language-data>=1.2->langcodes) (65.5.0)
#
# [notice] A new release of pip is available: 23.3.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
current_loc = os.getcwd()

print(current_loc)
# Out:
# /Users/jrhym/Desktop/Jordan/cp2

# %%
metadata_file_path = os.path.join('cp2','item-metadata')

print(metadata_file_path)
# Out:
# cp2/item-metadata

# %%
file_count = 0

for f in glob.glob('../cp2/item-metadata/item-metadata-*.json'):
    file_count += 1
    print(f)
    
print('found',file_count)
# Out:
# ../cp2/item-metadata/item-metadata-highsm.16470.json
# ../cp2/item-metadata/item-metadata-highsm.46917.json
# ../cp2/item-metadata/item-metadata-afc1991022.afc1991022_hh_002.json
# ../cp2/item-metadata/item-metadata-ggbain.10041.json
# ../cp2/item-metadata/item-metadata-thc.5a36385.json
# ../cp2/item-metadata/item-metadata-nclc.00972.json
# ../cp2/item-metadata/item-metadata-hec.40272.json
# ../cp2/item-metadata/item-metadata-det.4a31696.json
# ../cp2/item-metadata/item-metadata-cph.3b03723.json
# ../cp2/item-metadata/item-metadata-ppmsca.58753.json
# ../cp2/item-metadata/item-metadata-hec.07254.json
# ../cp2/item-metadata/item-metadata-var.0092.json
# ../cp2/item-metadata/item-metadata-cph.3b03958.json
# ../cp2/item-metadata/item-metadata-gdclccn.ca06001657v20n1.json
# ../cp2/item-metadata/item-metadata-ppmsca.01947.json
# ../cp2/item-metadata/item-metadata-cph.3b49065.json
# ../cp2/item-metadata/item-metadata-rbctos.2017gen16152v4.json
# ../cp2/item-metadata/item-metadata-fsa.8e03362.json
# ../cp2/item-metadata/item-metadata-ds.11694.json
# ../cp2/item-metadata/item-metadata-fsa.8c52874.json
# ../cp2/item-metadata/item-metadata-thc.5a36383.json
# ../cp2/item-metadata/item-metadata-fsa.8c22655.json
# ../cp2/item-metadata/item-metadata-stereo.1s14746.json
# ../cp2/item-metadata/item-metadata-ppmsca.58775.json
# ../cp2/item-metadata/item-metadata-ppmsca.44347.json
# ../cp2/item-metadata/item-metadata-pga.00121.json
# ../cp2/item-metadata/item-metadata-mrg.07416.json
# ../cp2/item-metadata/item-metadata-ppmsca.59523.json
# ../cp2/item-metadata/item-metadata-ppmsca.39602.json
# ../cp2/item-metadata/item-metadata-highsm.21033.json
# ../cp2/item-metadata/item-metadata-stereo.1s34429.json
# ../cp2/item-metadata/item-metadata-det.4a26655.json
# ../cp2/item-metadata/item-metadata-cph.3a49776.json
# ../cp2/item-metadata/item-metadata-pga.01210.json
# ../cp2/item-metadata/item-metadata-ppmsca.19492.json
# ../cp2/item-metadata/item-metadata-pga.09354.json
# ../cp2/item-metadata/item-metadata-cph.3c28076.json
# ../cp2/item-metadata/item-metadata-cph.3a47158.json
# ../cp2/item-metadata/item-metadata-ppmsca.18646.json
# ../cp2/item-metadata/item-metadata-afc1991022.afc1991022_tb_038.json
# ../cp2/item-metadata/item-metadata-cph.3b42820.json
# ../cp2/item-metadata/item-metadata-gdcmassbookdig.bookoffishes00nati_0.json
# ../cp2/item-metadata/item-metadata-fsa.8c35824.json
# ../cp2/item-metadata/item-metadata-ppmsca.09305.json
# ../cp2/item-metadata/item-metadata-ppmsca.44535.json
# ../cp2/item-metadata/item-metadata-ppmsca.41730.json
# ../cp2/item-metadata/item-metadata-ppmsc.05895.json
# ../cp2/item-metadata/item-metadata-det.4a12198.json
# ../cp2/item-metadata/item-metadata-jpd.00505.json
# ../cp2/item-metadata/item-metadata-ppmsc.02385.json
# found 50

# %%
list_of_item_metadata_files = list() 
for f in glob.glob('../cp2/item-metadata/item-metadata-*.json'):
    list_of_item_metadata_files.append(f)

len(list_of_item_metadata_files)
# Out:
# 50

# %%
#Check for duplicates

list_of_item_metadata_files.sort()

for f in list_of_item_metadata_files:
    print(f)
# Out:
# ../cp2/item-metadata/item-metadata-afc1991022.afc1991022_hh_002.json
# ../cp2/item-metadata/item-metadata-afc1991022.afc1991022_tb_038.json
# ../cp2/item-metadata/item-metadata-cph.3a47158.json
# ../cp2/item-metadata/item-metadata-cph.3a49776.json
# ../cp2/item-metadata/item-metadata-cph.3b03723.json
# ../cp2/item-metadata/item-metadata-cph.3b03958.json
# ../cp2/item-metadata/item-metadata-cph.3b42820.json
# ../cp2/item-metadata/item-metadata-cph.3b49065.json
# ../cp2/item-metadata/item-metadata-cph.3c28076.json
# ../cp2/item-metadata/item-metadata-det.4a12198.json
# ../cp2/item-metadata/item-metadata-det.4a26655.json
# ../cp2/item-metadata/item-metadata-det.4a31696.json
# ../cp2/item-metadata/item-metadata-ds.11694.json
# ../cp2/item-metadata/item-metadata-fsa.8c22655.json
# ../cp2/item-metadata/item-metadata-fsa.8c35824.json
# ../cp2/item-metadata/item-metadata-fsa.8c52874.json
# ../cp2/item-metadata/item-metadata-fsa.8e03362.json
# ../cp2/item-metadata/item-metadata-gdclccn.ca06001657v20n1.json
# ../cp2/item-metadata/item-metadata-gdcmassbookdig.bookoffishes00nati_0.json
# ../cp2/item-metadata/item-metadata-ggbain.10041.json
# ../cp2/item-metadata/item-metadata-hec.07254.json
# ../cp2/item-metadata/item-metadata-hec.40272.json
# ../cp2/item-metadata/item-metadata-highsm.16470.json
# ../cp2/item-metadata/item-metadata-highsm.21033.json
# ../cp2/item-metadata/item-metadata-highsm.46917.json
# ../cp2/item-metadata/item-metadata-jpd.00505.json
# ../cp2/item-metadata/item-metadata-mrg.07416.json
# ../cp2/item-metadata/item-metadata-nclc.00972.json
# ../cp2/item-metadata/item-metadata-pga.00121.json
# ../cp2/item-metadata/item-metadata-pga.01210.json
# ../cp2/item-metadata/item-metadata-pga.09354.json
# ../cp2/item-metadata/item-metadata-ppmsc.02385.json
# ../cp2/item-metadata/item-metadata-ppmsc.05895.json
# ../cp2/item-metadata/item-metadata-ppmsca.01947.json
# ../cp2/item-metadata/item-metadata-ppmsca.09305.json
# ../cp2/item-metadata/item-metadata-ppmsca.18646.json
# ../cp2/item-metadata/item-metadata-ppmsca.19492.json
# ../cp2/item-metadata/item-metadata-ppmsca.39602.json
# ../cp2/item-metadata/item-metadata-ppmsca.41730.json
# ../cp2/item-metadata/item-metadata-ppmsca.44347.json
# ../cp2/item-metadata/item-metadata-ppmsca.44535.json
# ../cp2/item-metadata/item-metadata-ppmsca.58753.json
# ../cp2/item-metadata/item-metadata-ppmsca.58775.json
# ../cp2/item-metadata/item-metadata-ppmsca.59523.json
# ../cp2/item-metadata/item-metadata-rbctos.2017gen16152v4.json
# ../cp2/item-metadata/item-metadata-stereo.1s14746.json
# ../cp2/item-metadata/item-metadata-stereo.1s34429.json
# ../cp2/item-metadata/item-metadata-thc.5a36383.json
# ../cp2/item-metadata/item-metadata-thc.5a36385.json
# ../cp2/item-metadata/item-metadata-var.0092.json

# %% [markdown]
# JSON Information Exploration

# %%
# Test a file: 1) can you open the json; 2) can you see what elements are in the json?
with open(list_of_item_metadata_files[0], 'r', encoding='utf-8') as item:
    # what are we looking at?
    print('file:',list_of_item_metadata_files[0],'\n')
    
    # load the item data
    item_data = json.load(item)
    
    for element in item_data.keys():
        print(element,':',item_data[element])
# Out:
# file: ../cp2/item-metadata/item-metadata-afc1991022.afc1991022_hh_002.json
#
# _version_ : 1775584457780101120
# access_restricted : False
# aka : ['http://www.loc.gov/item/afc1991022_hh_002/', 'https://hdl.loc.gov/loc.afc/afc1991022.afc1991022_hh_002', 'http://www.loc.gov/resource/afc1991022.afc1991022_hh_002/', 'http://www.loc.gov/item/afc1991022.afc1991022_hh_002/']
# call_number : ['Call number: AFC 1991/022: RI79-HH-2']
# campaigns : []
# contributor_names : ['Horenstein, Henry (Photographer)']
# contributors : [{'horenstein, henry': 'https://www.loc.gov/search/?fa=contributor:horenstein,+henry&fo=json'}]
# created_published : ['Narragansett, Rhode Island, August 20, 1979']
# date : 1979-08-20
# dates : [{'1979-08-20': 'https://www.loc.gov/search/?dates=1979-08-20/1979-08-20&fo=json'}]
# digital_id : ['https://hdl.loc.gov/loc.afc/afc1991022.afc1991022_hh_002']
# digitized : True
# display_offsite : True
# extract_timestamp : 2023-08-29T17:12:36.397Z
# extract_urls : ['http://c2vlpdmtool01.loc.gov/data-management-tool/export_group_xml/afc1991022/afc1991022_hh_002.xml#afc1991022']
# format : [{'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'}]
# genre : ['Photographs', 'Ethnography']
# group : ['afc1991022', 'rhode-island-folklife-project']
# hassegments : True
# id : http://www.loc.gov/item/afc1991022_hh_002/
# image_url : ['https://tile.loc.gov/image-services/iiif/service:afc:afc1991022:afc1991022_hh_002:afc1991022_hh_002_02/full/pct:6.25/0/default.jpg#h=315&w=217', 'https://tile.loc.gov/image-services/iiif/service:afc:afc1991022:afc1991022_hh_002:afc1991022_hh_002_02/full/pct:12.5/0/default.jpg#h=630&w=435', 'https://tile.loc.gov/image-services/iiif/service:afc:afc1991022:afc1991022_hh_002:afc1991022_hh_002_02/full/pct:25/0/default.jpg#h=1261&w=870', 'https://tile.loc.gov/image-services/iiif/service:afc:afc1991022:afc1991022_hh_002:afc1991022_hh_002_02/full/pct:50/0/default.jpg#h=2523&w=1740', 'https://tile.loc.gov/image-services/iiif/service:afc:afc1991022:afc1991022_hh_002:afc1991022_hh_002_02/full/pct:100/0/default.jpg#h=5047&w=3481']
# index : 1
# item : {'call_number': ['Call number: AFC 1991/022: RI79-HH-2'], 'contributors': ['Horenstein, Henry (Photographer)'], 'created_published': ['Narragansett, Rhode Island, August 20, 1979'], 'date': '19790820', 'digital_id': ['https://hdl.loc.gov/loc.afc/afc1991022.afc1991022_hh_002'], 'format': 'still image', 'genre': ['Photographs', 'Ethnography'], 'language': 'eng', 'location': ['United States -- Rhode Island -- Narragansett'], 'medium': ['35 mm color slide'], 'notes': ['Index data: 1-10, Kids fishing on Bonnet Shores; 11-19, Bonnet Shores Beach Club, including; 11-12, Martha Hoey and friend; 14-19, Tetherball game'], 'related_items': [{'title': 'Photo log for AFC 1991/022: RI79-HH-002 (part of AFC 1991/022: Box 7, Folder 120)', 'url': 'https://www.loc.gov/resource/afc1991022.afc1991022_07_120/?sp=3'}], 'repository': 'American Folklife Center', 'rights': 'No known restrictions on use or reproduction.', 'source_collection': 'Rhode Island Folklife Project collection, 1979 (AFC 1991/022)', 'subjects': ['Folklore--Rhode Island', 'Photographs', 'Ethnography', 'United States -- Rhode Island -- Narragansett'], 'title': 'Kids fishing, beach club, tetherball game, Bonnet Shores, Rhode Island'}
# language : ['english']
# languages : [{'english': 'https://www.loc.gov/search/?fa=language:english&fo=json'}]
# location : ['united states', 'narragansett', 'rhode island']
# locations : [{'narragansett': 'https://www.loc.gov/search/?fa=location:narragansett&fo=json'}, {'rhode island': 'https://www.loc.gov/search/?fa=location:rhode+island&fo=json'}, {'united states': 'https://www.loc.gov/search/?fa=location:united+states&fo=json'}]
# medium : ['35 mm color slide']
# mime_type : ['image/tiff', 'image/jpeg', 'image/jp2']
# notes : ['Index data: 1-10, Kids fishing on Bonnet Shores; 11-19, Bonnet Shores Beach Club, including; 11-12, Martha Hoey and friend; 14-19, Tetherball game']
# online_format : ['image']
# original_format : ['photo, print, drawing']
# other_formats : []
# partof : [{'count': 979, 'title': 'rhode island folklife project collection', 'url': 'https://www.loc.gov/collections/rhode-island-folklife-project/?fo=json'}, {'count': 176657, 'title': 'american folklife center', 'url': 'https://www.loc.gov/search/?fa=partof:american+folklife+center&fo=json'}]
# related_items : [{'title': 'Photo log for AFC 1991/022: RI79-HH-002 (part of AFC 1991/022: Box 7, Folder 120)', 'url': 'https://www.loc.gov/resource/afc1991022.afc1991022_07_120/?sp=3'}]
# repository : ['American Folklife Center']
# resources : [{'files': 19, 'image': 'https://tile.loc.gov/image-services/iiif/service:afc:afc1991022:afc1991022_hh_002:afc1991022_hh_002_02/full/pct:6.25/0/default.jpg', 'representative_index': 1, 'url': 'https://www.loc.gov/resource/afc1991022.afc1991022_hh_002/'}]
# rights : ['<p>The Library of Congress believes that some of the materials in this collection are in the public domain or have no known copyright restrictions, and are therefore free to use or reuse. For example, the fieldwork in this collection is in the public domain in the United States. </p>\r\n<p>However, the Library has obtained permission for the use of other materials, and presents additional materials for educational and research purposes in accordance with fair use under United States copyright law. For example, some of the recordings contain copyrighted music, and not all of the performers and other individuals who were recorded signed releases for public use of their work. </p>\r\n<p>In addition, the American Folklife Center and the professional fieldworkers who carry out these projects feel a strong ethical responsibility to the people they have visited and who have consented to have their lives documented for the historical record. The Center asks that researchers approach the materials in this collection with respect for the culture and sensibilities of the people whose lives, ideas, and creativity are documented here. Researchers are also reminded that privacy and publicity rights may pertain to certain uses of this material. </p>\r\n<p>Researchers or others who would like to make further use of these collection materials should contact the <a href="http://hdl.loc.gov/loc.afc/folklife.contact">Folklife Reading Room</a> for assistance.  Rights assessment is your responsibility.  The written permission of the copyright owners in materials not in the public domain is required for distribution, reproduction, or other use of protected items beyond that allowed by fair use or other statutory exemptions. Permissions may additionally be required from holders of other rights (such as publicity and/or privacy rights). Whenever possible, we provide information that we have about copyright owners and related matters in the catalog records, finding aids and other texts that accompany collections. However, the information we have may not be accurate or complete.</p>\r\n<p>More about <a href="/legal/">Copyright and other Restrictions</a></p>\r\n<p>For guidance about compiling full citations consult <a href="https://www.loc.gov/teachers/usingprimarysources/citing.html">Citing Primary Sources</a>.</p>\r\n<p><strong>Credit line:</strong> Rhode Island Folklife Project collection (AFC 1991/022), American Folklife Center, Library of Congress</p>\r\n\r\n']
# score : 16.901009
# shard : 01
# shelf_id : Call number: AFC 1991/022: RI79-HH-2
# source_collection : Rhode Island Folklife Project collection, 1979 (AFC 1991/022)
# source_modified : 2000-01-01T12:00:00Z
# subject : ['ethnography', 'photographs', 'rhode island', 'folklore']
# subject_headings : ['Folklore--Rhode Island', 'Photographs', 'Ethnography', 'United States -- Rhode Island -- Narragansett']
# subjects : [{'ethnography': 'https://www.loc.gov/search/?fa=subject:ethnography&fo=json'}, {'folklore': 'https://www.loc.gov/search/?fa=subject:folklore&fo=json'}, {'photographs': 'https://www.loc.gov/search/?fa=subject:photographs&fo=json'}, {'rhode island': 'https://www.loc.gov/search/?fa=subject:rhode+island&fo=json'}]
# timestamp : 2023-08-29T17:14:53.833Z
# title : Kids fishing, beach club, tetherball game, Bonnet Shores, Rhode Island
# type : ['photo, print, drawing']
# url : https://www.loc.gov/item/afc1991022_hh_002/

# %%
item_data.keys()
# Out:
# dict_keys(['_version_', 'access_restricted', 'aka', 'call_number', 'campaigns', 'contributor_names', 'contributors', 'created_published', 'date', 'dates', 'digital_id', 'digitized', 'display_offsite', 'extract_timestamp', 'extract_urls', 'format', 'genre', 'group', 'hassegments', 'id', 'image_url', 'index', 'item', 'language', 'languages', 'location', 'locations', 'medium', 'mime_type', 'notes', 'online_format', 'original_format', 'other_formats', 'partof', 'related_items', 'repository', 'resources', 'rights', 'score', 'shard', 'shelf_id', 'source_collection', 'source_modified', 'subject', 'subject_headings', 'subjects', 'timestamp', 'title', 'type', 'url'])

# %%
# can you get the date?
print('\ndate:',item_data['date'], type(item_data['date']))

# can you get the format?
print('\nformat:',item_data['format'][0], type(item_data['format']))
# Out:
# date: 1979-08-20 <class 'str'>
#
# format: {'photo, print, drawing': 'https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json'} <class 'list'>

# %% [markdown]
# Create CSV Container for the Transformation Process

# %%
#CSV Container File
collection2_info_csv = 'collection2_items_data.csv'

#CSV Column Headers
headers = ['identifier', 'creator', 'date', 'title', 'subjects', 'description', 'location', 'physical_description',  'language', 'file_type', 'source_collection', 'rights']


#Test CVS File
with open(list_of_item_metadata_files[13], 'r', encoding='utf-8') as data:
    item_data = json.load(data)

    source_file = str(f)
#Identifier    
    try:
        item_id = item_data['digital_id'][0].split()[-1]
    except:
        item_id = 'Not found'
#Creator
    try: 
        item_creator = ' '.join(item_data['contributor_names'][0].split(', ')[:-1])
    except:
        item_creator = 'Not found'
#Date
    def convert_to_iso_date(text):
        # Strip non-date material
        text = text.strip()

        # Define the regex patterns for different date formats
        patterns = [
            # YYYY-MM-DD
            r'(\d{4})[-/](\d{1,2})[-/](\d{1,2})',
            # YYYY-MM
            r'(\d{4})[-/](\d{1,2})',
            # YYYY
            r'\b(\d{4})\b'
        ]
        for pattern in patterns:
            match = re.search(pattern, text)
            if match:
                groups = match.groups()

                try:
                    if len(groups) == 3:
                        # Full date (YYYY-MM-DD)
                        date = datetime.strptime(f"{groups[0]}-{groups[1]}-{groups[2]}", "%Y-%m-%d")
                        return date.strftime("%Y-%m-%d")
                    elif len(groups) == 2:
                        # Year and Month (YYYY-MM)
                        month = int(groups[1])
                        if 1 <= month <= 12:
                            return f"{groups[0]}-{month:02d}"
                    elif len(groups) == 1:
                        # Year only (YYYY)
                        year = groups[0]
                        year = re.sub(r'\D', '', year)
                        if 1000 <= int(year) <= 9999:
                            return year
                except (ValueError, IndexError):
                    continue  

        return 'Not found'
    try:
        item_date = convert_to_iso_date(item_data['date'])
    except:
        item_date = 'Not found'
#Title
    try:
        item_title = item_data['title']
    except:
        item_title = 'Not found'
#Subjects
    try:
        item_subjects = ', '.join([list(subject.keys())[0] for subject in item_data['subjects']])

        # subject_names = [list(subject.keys())[0] for subject in subjects]
    except:
        item_subjects = 'Not found'
    # try:
    #     item_subjects = item_data['subjects']
    # except:
    #     item_subjects = 'Not found'
#Description
    try:
        item_description = item_data['description'][0]
    except:
        item_description = 'Not found'
#Location
    try:
        item_location = ', '.join(word.capitalize() for word in item_data['location'])
    except:
        item_location = 'Not found'
#Physical Description
    try:
        item_physical_description = list(item_data['format'][0].keys())[0]
    except:
        item_physical_description = 'Not found'
#Language

    def convert_to_iso639(languages):
        language_codes = {
        "english": "eng",
        "french": "fra",
        "spanish": "spa",
        "german": "deu",
        "italian": "ita",
        "portuguese": "por",
        "russian": "rus",
        "japanese": "jpn",
        "chinese": "zho",
        "korean": "kor",
        "arabic": "ara",
        "hindi": "hin",
        "turkish": "tur",
        "vietnamese": "vie",
        "thai": "tha",
        "dutch": "nld",
        "greek": "ell",
        "polish": "pol",
        "swedish": "swe",
        "danish": "dan",
        "finnish": "fin",
        "norwegian": "nor",
        "czech": "ces",
        "hungarian": "hun",
        "romanian": "ron"
    }
        return [language_codes.get(lang.lower()) for lang in languages]
    try:
        item_language = ' '.join(convert_to_iso639(item_data['language']))
    except:
        item_language = 'Not found'
    # def iso_639_2(lang):
    #     try:
    #         return lang.iso_639_2()
    #     except:
    #         return 'Not found'
    #     item_language = iso_639_2(item_data['language'])

#File Type
    try:
        item_file_type = '; '.join(item_data['mime_type'])
    except:
        item_file_type = 'Not found'
#Source Collection
    try:
        item_source_collection = ', '.join([entry['title'] for entry in item_data['partof']])
    except:
        item_source_collection = 'Not found'
#Rights
    try:
        item_rights = item_data['rights_advisory']
    except:
        item_rights = 'Undetermined'


#CREATE Dictionary for the rows
row_dict = dict()

row_dict['identifier'] = item_id
row_dict['creator'] = item_creator
row_dict['date'] = item_date
row_dict['title'] = item_title
row_dict['subjects'] = item_subjects
row_dict['description'] = item_description
row_dict['location'] = item_location
row_dict['physical_description'] = item_physical_description
row_dict['language'] = item_language
row_dict['file_type'] = item_file_type
row_dict['source_collection'] = item_source_collection
row_dict['rights'] = item_rights

print('row dictionary created:', row_dict)

#Write the row to the CSV file
with open(collection2_info_csv, 'w', newline='', encoding='utf-8') as fout:
    writer = csv.DictWriter(fout, fieldnames=headers)
    writer.writeheader()
    writer.writerow(row_dict)
    print('wrote', collection2_info_csv)
# Out:
# row dictionary created: {'identifier': '//hdl.loc.gov/loc.pnp/fsa.8c22655', 'creator': 'Lee Russell 1903-1986', 'date': '1941-01-01', 'title': 'Fishing boat. Astoria, Oregon', 'subjects': 'astoria, clatsop county, oregon, safety film negatives, united states', 'description': '1 negative : safety ; 3 1/4 x 4 1/4 inches or smaller.', 'location': 'Astoria, Oregon, Clatsop county, United states', 'physical_description': 'photo, print, drawing', 'language': 'eng', 'file_type': 'image/gif; image/jpg; image/tif', 'source_collection': 'lot 338, farm security administration/office of war information black-and-white negatives, american memory, prints & photographs online catalog (library of congress), prints and photographs division, catalog', 'rights': 'No known restrictions. For information, see U.S. Farm Security Administration/Office of War Information Black & White Photographs https://www.loc.gov/rr/print/res/071_fsab.html'}
# wrote collection2_items_data.csv

# %%
collection2_info_csv = 'collection2_items_data.csv'

# set up a list for the columns in your csv; in future, this should be more automated but this works for now as you set up the crosswalk
headers = ['identifier', 'creator', 'date', 'title', 'subjects', 'description', 'location', 'physical_description',  'language', 'file_type', 'source_collection', 'rights']

# try first with one file
with open(list_of_item_metadata_files[0], 'r', encoding='utf-8') as data:
    # load the item data
    item_data = json.load(data)
    
    print(item_data['image_url'][3])
# Out:
# https://tile.loc.gov/image-services/iiif/service:afc:afc1991022:afc1991022_hh_002:afc1991022_hh_002_02/full/pct:50/0/default.jpg#h=2523&w=1740

# %% [markdown]
# Writing and Formatting the CSV File

# %%
items_data_file = os.path.join('collection2_items_data.csv')

if os.path.isfile(items_data_file):
    os.unlink(items_data_file)
    print('removed',items_data_file)

# clear row_dict
row_dict = ()
# Out:
# removed collection2_items_data.csv

# %%
from datetime import date

date_string_for_today = date.today().strftime('%Y-%m-%d')

print(date_string_for_today)
# Out:
# 2024-12-18

# %%
collection2_info_csv = os.path.join('..','CP2','collection2_items_data.csv')
file_count = 0
items_written = 0
error_count = 0

headers = ['identifier', 'creator', 'date', 'title', 'subjects', 'description', 'location', 'physical_description',  'language', 'file_type', 'source_collection', 'rights', 'image_url']

for file in list_of_item_metadata_files:
    file_count += 1
    print('opening',file)
    with open(file, 'r', encoding='utf-8') as item:
        try:
            item_data = json.load(item)
        except:
            print('error loading',file)
            error_count += 1
            continue

        item_type = 'Item'
        date_uploaded = date_string_for_today
        source_file = str(file)

        #Extract data and format row dict()
        #Identifier    
        try:
            item_id = item_data['digital_id'][0].split()[-1]
        except:
            item_id = 'Not found'
        #Creator
        try: 
            item_creator = ' '.join(item_data['contributor_names'][0].split(', ')[:-1])
        except:
            item_creator = 'Not found'
        #Date
        #Come back and conform to ISO format
        def convert_to_iso_date(text):
            # Strip non-date material
            text = text.strip()

            # Define the regex patterns for different date formats
            patterns = [
                # YYYY-MM-DD
                r'(\d{4})[-/](\d{1,2})[-/](\d{1,2})',
                # YYYY-MM
                r'(\d{4})[-/](\d{1,2})',
                # YYYY
                r'\b(\d{4})\b'
            ]
            for pattern in patterns:
                match = re.search(pattern, text)
                if match:
                    groups = match.groups()

                    try:
                        if len(groups) == 3:
                            # Full date (YYYY-MM-DD)
                            date = datetime.strptime(f"{groups[0]}-{groups[1]}-{groups[2]}", "%Y-%m-%d")
                            return date.strftime("%Y-%m-%d")
                        elif len(groups) == 2:
                            # Year and Month (YYYY-MM)
                            month = int(groups[1])
                            if 1 <= month <= 12:
                                return f"{groups[0]}-{month:02d}"
                        elif len(groups) == 1:
                            # Year only (YYYY)
                            year = groups[0]
                            year = re.sub(r'\D', '', year)
                            if 1000 <= int(year) <= 9999:
                                return year
                    except (ValueError, IndexError):
                        continue  

            return 'Not found'
        try:
            item_date = convert_to_iso_date(item_data['date'])
        except:
            item_date = 'Not found'
        #Title
        try:
            item_title = item_data['title']
        except:
            item_title = 'Not found'
        #Subjects
        try:
            item_subjects = ', '.join([list(subject.keys())[0] for subject in item_data['subjects']])

        except:
            item_subjects = 'Not found'
        #Description
        try:
            item_description = item_data['description'][0]
        except:
            item_description = 'Not found'
        #Location
        try:
            item_location = ', '.join(word.capitalize() for word in item_data['location'])
        except:
            item_location = 'Not found'
        #Physical Description
        try:
            item_physical_description = list(item_data['format'][0].keys())[0]
        except:
            item_physical_description = 'Not found'
        #Language
        def convert_to_iso639(languages):
            language_codes = {
            "english": "eng",
            "french": "fra",
            "spanish": "spa",
            "german": "deu",
            "italian": "ita",
            "portuguese": "por",
            "russian": "rus",
            "japanese": "jpn",
            "chinese": "zho",
            "korean": "kor",
            "arabic": "ara",
            "hindi": "hin",
            "turkish": "tur",
            "vietnamese": "vie",
            "thai": "tha",
            "dutch": "nld",
            "greek": "ell",
            "polish": "pol",
            "swedish": "swe",
            "danish": "dan",
            "finnish": "fin",
            "norwegian": "nor",
            "czech": "ces",
            "hungarian": "hun",
            "romanian": "ron"
        }
            return [language_codes.get(lang.lower()) for lang in languages]
        try:
            item_language = ' '.join(convert_to_iso639(item_data['language']))
        except:
            item_language = 'Not found'
        #File Type
        try:
            item_file_type = '; '.join(item_data['mime_type'])
        except:
            item_file_type = 'Not found'
        #Source Collection
        try:
            item_source_collection = ', '.join([entry['title'] for entry in item_data['partof']])
        except:
            item_source_collection = 'Not found'
        #Rights
        try:
            item_rights = item_data['rights_advisory']
        except:
            item_rights = 'Undetermined'
        #Image URL
        try:
            item_image_url = item_data['image_url'][2]
        except:
            item_image_url = 'Image URL not found'


        #CREATE Dictionary for the rows
        row_dict = dict()

        row_dict['identifier'] = item_id
        row_dict['creator'] = item_creator
        row_dict['date'] = item_date
        row_dict['title'] = item_title
        row_dict['subjects'] = item_subjects
        row_dict['description'] = item_description
        row_dict['location'] = item_location
        row_dict['physical_description'] = item_physical_description
        row_dict['language'] = item_language
        row_dict['file_type'] = item_file_type
        row_dict['source_collection'] = item_source_collection
        row_dict['rights'] = item_rights
        row_dict['image_url'] = item_image_url

        with open(collection2_info_csv, 'a', encoding='utf-8', newline='') as fout:
            writer = csv.DictWriter(fout, fieldnames=headers)
            if items_written == 0:
                writer.writeheader()
            writer.writerow(row_dict)
            items_written += 1
            print('adding', item_id)

print('\n\n--- LOG ---')
print('wrote',collection2_info_csv)
print('with',items_written,'items')
print(error_count,'errors (info not written)')
# Out:
# opening ../cp2/item-metadata/item-metadata-afc1991022.afc1991022_hh_002.json
# adding https://hdl.loc.gov/loc.afc/afc1991022.afc1991022_hh_002
# opening ../cp2/item-metadata/item-metadata-afc1991022.afc1991022_tb_038.json
# adding https://hdl.loc.gov/loc.afc/afc1991022.afc1991022_tb_038
# opening ../cp2/item-metadata/item-metadata-cph.3a47158.json
# adding //hdl.loc.gov/loc.pnp/ds.15204
# opening ../cp2/item-metadata/item-metadata-cph.3a49776.json
# adding //hdl.loc.gov/loc.pnp/cph.3a49776
# opening ../cp2/item-metadata/item-metadata-cph.3b03723.json
# adding //hdl.loc.gov/loc.pnp/ds.15146
# opening ../cp2/item-metadata/item-metadata-cph.3b03958.json
# adding //hdl.loc.gov/loc.pnp/cph.3b03958
# opening ../cp2/item-metadata/item-metadata-cph.3b42820.json
# adding //hdl.loc.gov/loc.pnp/cph.3b42820
# opening ../cp2/item-metadata/item-metadata-cph.3b49065.json
# adding https://hdl.loc.gov/loc.pnp/ds.16750
# opening ../cp2/item-metadata/item-metadata-cph.3c28076.json
# adding https://hdl.loc.gov/loc.pnp/cph.3c28076
# opening ../cp2/item-metadata/item-metadata-det.4a12198.json
# adding //hdl.loc.gov/loc.pnp/det.4a12198
# opening ../cp2/item-metadata/item-metadata-det.4a26655.json
# adding //hdl.loc.gov/loc.pnp/det.4a26655
# opening ../cp2/item-metadata/item-metadata-det.4a31696.json
# adding https://hdl.loc.gov/loc.pnp/det.4a31696
# opening ../cp2/item-metadata/item-metadata-ds.11694.json
# adding https://hdl.loc.gov/loc.pnp/ds.11694
# opening ../cp2/item-metadata/item-metadata-fsa.8c22655.json
# adding //hdl.loc.gov/loc.pnp/fsa.8c22655
# opening ../cp2/item-metadata/item-metadata-fsa.8c35824.json
# adding //hdl.loc.gov/loc.pnp/fsa.8c35824
# opening ../cp2/item-metadata/item-metadata-fsa.8c52874.json
# adding https://hdl.loc.gov/loc.pnp/fsa.8c52874
# opening ../cp2/item-metadata/item-metadata-fsa.8e03362.json
# adding //hdl.loc.gov/loc.pnp/fsa.8e03362
# opening ../cp2/item-metadata/item-metadata-gdclccn.ca06001657v20n1.json
# adding https://hdl.loc.gov/loc.gdc/gdclccn.ca06001657v20n1
# opening ../cp2/item-metadata/item-metadata-gdcmassbookdig.bookoffishes00nati_0.json
# adding Not found
# opening ../cp2/item-metadata/item-metadata-ggbain.10041.json
# adding //hdl.loc.gov/loc.pnp/ggbain.10041
# opening ../cp2/item-metadata/item-metadata-hec.07254.json
# adding //hdl.loc.gov/loc.pnp/hec.07254
# opening ../cp2/item-metadata/item-metadata-hec.40272.json
# adding //hdl.loc.gov/loc.pnp/hec.40272
# opening ../cp2/item-metadata/item-metadata-highsm.16470.json
# adding https://hdl.loc.gov/loc.pnp/highsm.16470
# opening ../cp2/item-metadata/item-metadata-highsm.21033.json
# adding //hdl.loc.gov/loc.pnp/highsm.21033
# opening ../cp2/item-metadata/item-metadata-highsm.46917.json
# adding //hdl.loc.gov/loc.pnp/highsm.46917
# opening ../cp2/item-metadata/item-metadata-jpd.00505.json
# adding //hdl.loc.gov/loc.pnp/jpd.00505
# opening ../cp2/item-metadata/item-metadata-mrg.07416.json
# adding https://hdl.loc.gov/loc.pnp/mrg.07416
# opening ../cp2/item-metadata/item-metadata-nclc.00972.json
# adding https://hdl.loc.gov/loc.pnp/nclc.00972
# opening ../cp2/item-metadata/item-metadata-pga.00121.json
# adding //hdl.loc.gov/loc.pnp/pga.00121
# opening ../cp2/item-metadata/item-metadata-pga.01210.json
# adding //hdl.loc.gov/loc.pnp/pga.01210
# opening ../cp2/item-metadata/item-metadata-pga.09354.json
# adding //hdl.loc.gov/loc.pnp/pga.09354
# opening ../cp2/item-metadata/item-metadata-ppmsc.02385.json
# adding http://hdl.loc.gov/loc.pnp/ppmsc.02385
# opening ../cp2/item-metadata/item-metadata-ppmsc.05895.json
# adding //hdl.loc.gov/loc.pnp/ppmsc.05895
# opening ../cp2/item-metadata/item-metadata-ppmsca.01947.json
# adding https://hdl.loc.gov/loc.pnp/ppmsca.01947
# opening ../cp2/item-metadata/item-metadata-ppmsca.09305.json
# adding //hdl.loc.gov/loc.pnp/ppmsca.09305
# opening ../cp2/item-metadata/item-metadata-ppmsca.18646.json
# adding https://hdl.loc.gov/loc.pnp/ppmsca.18646
# opening ../cp2/item-metadata/item-metadata-ppmsca.19492.json
# adding //hdl.loc.gov/loc.pnp/ppmsca.19492
# opening ../cp2/item-metadata/item-metadata-ppmsca.39602.json
# adding //hdl.loc.gov/loc.pnp/ppmsca.39602
# opening ../cp2/item-metadata/item-metadata-ppmsca.41730.json
# adding //hdl.loc.gov/loc.pnp/ppmsca.41730
# opening ../cp2/item-metadata/item-metadata-ppmsca.44347.json
# adding https://hdl.loc.gov/loc.pnp/ppmsca.44347
# opening ../cp2/item-metadata/item-metadata-ppmsca.44535.json
# adding https://hdl.loc.gov/loc.pnp/ppmsca.44535
# opening ../cp2/item-metadata/item-metadata-ppmsca.58753.json
# adding https://hdl.loc.gov/loc.pnp/ppmsca.58753
# opening ../cp2/item-metadata/item-metadata-ppmsca.58775.json
# adding https://hdl.loc.gov/loc.pnp/ppmsca.58775
# opening ../cp2/item-metadata/item-metadata-ppmsca.59523.json
# adding https://hdl.loc.gov/loc.pnp/ppmsca.59523
# opening ../cp2/item-metadata/item-metadata-rbctos.2017gen16152v4.json
# adding http://hdl.loc.gov/loc.rbc/General.16152v1.1
# opening ../cp2/item-metadata/item-metadata-stereo.1s14746.json
# adding //hdl.loc.gov/loc.pnp/stereo.1s14746
# opening ../cp2/item-metadata/item-metadata-stereo.1s34429.json
# adding //hdl.loc.gov/loc.pnp/stereo.1s34429
# opening ../cp2/item-metadata/item-metadata-thc.5a36383.json
# adding https://hdl.loc.gov/loc.pnp/thc.5a36383
# opening ../cp2/item-metadata/item-metadata-thc.5a36385.json
# adding https://hdl.loc.gov/loc.pnp/thc.5a36385
# opening ../cp2/item-metadata/item-metadata-var.0092.json
# adding //hdl.loc.gov/loc.pnp/var.0092
#
#
# --- LOG ---
# wrote ../CP2/collection2_items_data.csv
# with 50 items
# 0 errors (info not written)
